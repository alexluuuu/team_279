# %%
from utils.colors import *
from utils.segmentation import *
from utils.DatasetPrep import GatherImageSet
from skimage import io
import matplotlib.pyplot as plt

# %% [markdown]
# The following cell segments the available images

# %%
image_dir = 'sample_dataset/images/'
num_imgs, imgs = GatherImageSet(image_dir)

image = io.imread(image_dir+imgs[41])
segment = compute_segmentation(image, 3, clustering_fn=kmeans_fast, \
                               feature_fn=color_position_features, scale=0.1)
center = getCenterSegment(image, segment)
plt.figure()
ax1 = plt.subplot(131)
plt.imshow(image)
ax2 = plt.subplot(132)
plt.imshow(segment, cmap='viridis')
plt.setp(ax2.get_yticklabels(), visible=False)
ax3 = plt.subplot(133)
plt.imshow(center)
plt.setp(ax3.get_yticklabels(), visible=False)
plt.show()

# %% [markdown]
# The following cell extracts the color histogram (name changed)

# %%
for i in range(num_imgs):
    image = io.imread(image_dir+imgs[i])
    color_feats = extractColorHistogram(image)
    if i == 1: break
# Out:
# [  9.51006665e-03   3.96481825e-02   2.04081633e-03   0.00000000e+00
#    9.44822373e-04   4.23280423e-03   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    1.64570879e-03   1.52202295e-03   3.43571772e-06   0.00000000e+00
#    3.43571772e-06   5.84072013e-05   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    1.54607297e-04   3.43571772e-06   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    4.81000481e-05   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
# ...
